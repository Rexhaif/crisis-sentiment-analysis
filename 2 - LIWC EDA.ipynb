# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = (20.0, 20.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/from-liwc/LIWC2015-Results-(sandy_hurricane).csv")

# %%
df.head()
# Out:
#                     A                                                  B  WC  \
# 0  263044104500420609  Sandy be soooo mad that she be shattering our ...  13
# 1  263101347421888513  Neighborly duties. @Cory_Kennedy arrives to th...  20
# 2  263298821189156865  I don't know how I'm getting back to Jersey si...  16
# 3  262914476989358080  Already flooded so much #SANDY @ Hoboken http:...  11
# 4  262991999911743490  On that note, i pray that everyone stays safe,...  15
#
#    Analytic  Clout  Authentic   Tone   WPS  Sixltr    Dic  ...  Comma  Colon  \
# 0      1.00  98.93       1.00   1.00  13.0   15.38  76.92  ...   0.00    0.0
# 1     98.58  84.14       3.37  25.77  10.0   35.00  50.00  ...   0.00    0.0
# 2      1.92   1.00      99.00  25.77  16.0   18.75  81.25  ...   0.00    0.0
# 3     32.58  50.00       2.40  25.77  11.0   36.36  54.55  ...   0.00    0.0
# 4     52.71  50.00      43.37  99.00   7.5   26.67  80.00  ...  13.33    0.0
#
# ...

# %%
df.columns
# Out:
# Index(['A', 'B', 'WC', 'Analytic', 'Clout', 'Authentic', 'Tone', 'WPS',
#        'Sixltr', 'Dic', 'function', 'pronoun', 'ppron', 'i', 'we', 'you',
#        'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb',
#        'conj', 'negate', 'verb', 'adj', 'compare', 'interrog', 'number',
#        'quant', 'affect', 'posemo', 'negemo', 'anx', 'anger', 'sad', 'social',
#        'family', 'friend', 'female', 'male', 'cogproc', 'insight', 'cause',
#        'discrep', 'tentat', 'certain', 'differ', 'percept', 'see', 'hear',
#        'feel', 'bio', 'body', 'health', 'sexual', 'ingest', 'drives',
#        'affiliation', 'achieve', 'power', 'reward', 'risk', 'focuspast',
#        'focuspresent', 'focusfuture', 'relativ', 'motion', 'space', 'time',
#        'work', 'leisure', 'home', 'money', 'relig', 'death', 'informal',
#        'swear', 'netspeak', 'assent', 'nonflu', 'filler', 'AllPunc', 'Period',
#        'Comma', 'Colon', 'SemiC', 'QMark', 'Exclam', 'Dash', 'Quote',
# ...

# %%
_ = sns.kdeplot(df.negemo, shade=True)
plt.plot()
# Out:
# []

# %%
with sns.axes_style("white", rc=plt.rcParams):
    sns.jointplot(x='negemo', y='Analytic', data=df, color='g', kind='kde')

# %%
sns.pairplot(df.loc[:,['negemo', 'posemo']])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1a6fe1782b2f> in <module>
# ----> 1 sns.pairplot(df)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2085
#    2086     # Add the markers here as PairGrid has figured out how many levels of the
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, height, aspect, despine, dropna, size)
# ...
